# %%
print("I AM SAID AHMED")
# Out:
# I AM SAID AHMED

# %%
x=1000
y=2000
y=y+2
print(id(x))
print(id(y))
print(x)
print(y)
# Out:
# 2036301759408
# 2036301758672
# 1000
# 2002

# %%
fruits = ["apple", "banana", "mango", "orange", "grapes", "watermelon",  "strawberry", "papaya", "guava"]
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange', 'grapes', 'watermelon', 'strawberry', 'papaya', 'guava']

# %%
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'grapes', 'guava', 'mango', 'orange', 'papaya', 'strawberry', 'watermelon']

# %% [markdown]
# Shallow Copy and Deep Copy

# %%
a = [10, 20, 30]
print(a)
# Out:
# [10, 20, 30]

# %%
b=a
print(b)
# Out:
# [10, 20, 30]

# %%
b.append(40)
print(a)
print(b)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %% [markdown]
# kio ye ?
# kio k a aur b ke paas same object ka reference hai

# %%
b = a.copy()

b.append(40)

print(a)
print(b)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40, 40]

# %% [markdown]
# a → [10, 20, 30]
#
# b → [10, 20, 30, 40]
#
# Ye shallow copy hai.

# %%
fruits = ["apple", "banana", ["mango", "orange", "grapes", "kiwi"],"graps"]
print(fruits)
# Out:
# ['apple', 'banana', ['mango', 'orange', 'grapes', 'kiwi'], 'graps']

# %%
print(fruits[2][1])
# Out:
# orange

# %%
print(fruits[1])
# Out:
# banana

# %%
fruit1 = [
    ['apple', 'banana'],
    ['mango', 'orange'],
    ['grapes', 'graps2']
]
print(fruit1)
# Out:
# [['apple', 'banana'], ['mango', 'orange'], ['grapes', 'graps2']]

# %%
print(fruit1[1][1][1]) #
# Out:
# r

# %% [markdown]
# Tuples

# %%
vegetable1 = ("potato", "tomato", "onion", "carrot", "spinach")
print(vegetable1)
# Out:
# ('potato', 'tomato', 'onion', 'carrot', 'spinach')

# %%
vegetable2 = ("cabbage", "peas", "radish", "turnip", "corn")
print(vegetable2)
# Out:
# ('cabbage', 'peas', 'radish', 'turnip', 'corn')

# %%
vegetable1[-1]
# Out:
# 'spinach'

# %%
vegetable1 = ("potato", "tomato", "onion", "carrot", "spinach")
vegetable2 = ("cabbage", "peas", "radish", "turnip", "corn")

# %%
print(vegetable1 == vegetable2)
# Out:
# False

# %%
veginlist =list(vegetable1)
print(veginlist)
# Out:
# ['potato', 'tomato', 'onion', 'carrot', 'spinach']

# %%
veginlist.append("cucumber")
print(veginlist)
# Out:
# ['potato', 'tomato', 'onion', 'carrot', 'spinach', 'cucumber']

# %%
vegintubleagain = tuple(veginlist)
print(vegintubleagain)
# Out:
# ('potato', 'tomato', 'onion', 'carrot', 'spinach', 'cucumber')

# %% [markdown]
# Dictionary

# %%
fruits_dict_1 = {"A": "apple", "B": "banana", "C": "mango"}
fruits_dict_2 = {"D": "orange", "E": "grapes", "F": "watermelon"}

print(fruits_dict_1)
print(fruits_dict_2)
# Out:
# {'A': 'apple', 'B': 'banana', 'C': 'mango'}
# {'D': 'orange', 'E': 'grapes', 'F': 'watermelon'}

# %%
print(fruits_dict_1["A"])
# Out:
# apple

# %%
# Dictionary Initialization
students = {'Roll no': [101, 102, 103], 'Name': ['Ali', 'Ahmad', 'Amir']}

# %%
print(students['Name'][0])
print(students['Name'][:])
# Out:
# Ali
# ['Ali', 'Ahmad', 'Amir']

# %%
sequence = ('apple', 'banana', 'cherry')
new_dict = dict.fromkeys(sequence, 0)
print(new_dict)
# Out:
# {'apple': 0, 'banana': 0, 'cherry': 0}

# %%
fruits_dict_1["A"]
# Out:
# 'apple'

# %%
fruits_dict_1.get("D")
